# %% [markdown]
# <a href="https://colab.research.google.com/github/yanapatt/Skin-Cancer-Classification-CNN/blob/main/PreparationDataset.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Preparation Dataset**
# ---
# **คำอธิบาย**
# ไฟล์ Jupyter notebook นี้ใช้สำหรับการจัดเตรียมรูปภาพให้พร้อมก่อนที่จะนำภาพเข้าโมเดล CNN ซึ่งประกอบไปด้วย
#
# 1.   การโหลด Dataset จาก Kaggle
# 2.   การจัดเตรียม Directory สำหรับดึง Image ไปใช้งาน
# 3.   การแบ่งข้อมูล Training, Validation และ Testing โดยเก็บเป็น Index ในรูปแบบ .csv เพื่อใช้ซ้ำในครั้งถัดไป
# 4.   การ Visualization images เพื่อรายงานผลเบื้องต้นเกี่ยวกับ Dataset
# 5.   เสริมการแก้ Imbalanced Dataset ด้วยการ Augmentation
#
# ---
# **Group Oscar Do Everything**
# **หัวข้อ Smart Skin Cancer Assistant CNN Model**
# **สมาชิก**
#
# * 66102010137	นายณัฐนนท์ หลิมเหล็ก
# * 66102010145	นายพชรดนัย กุระกนก
# * 66102010153	นายศิลายุชย์ โชติธรรมาภรณ์
# * 66102010236	นายญาณภัทร ปานเกษม
#
# **รายวิชา**
# **CP461 Introduction to Computer Vision**
#
# **Main Reference : An Interpretable Deep Learning Approach for Skin Cancer Categorization**
#
# **Paper Link:** https://arxiv.org/abs/2312.10696
# **GitHub:** https://github.com/Faysal-MD/An-Interpretable-Deep-Learning-Approach-for-Skin-Cancer-Categorization-IEEE2023?utm_source=chatgpt.com
# **EDA:** https://www.kaggle.com/code/abhishekgbhat/eda-cnn-architecture-tuning-80-83-accuracy#Univariate-EDA

# %% [markdown]
# ## **Section 0: Import important library**

# %%
import pandas as pd
import numpy as np
import random as rd
import tensorflow as tf
import keras
import sklearn
import joblib

import kagglehub
import os
import shutil
import glob
from tqdm import tqdm
import albumentations as A
import pathlib

import matplotlib.pyplot as plt
import matplotlib.font_manager as fm
import seaborn as sns
import missingno as msno
import cv2
from PIL import Image
import scipy.stats as ss

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ### **Setting a seed system environment**

# %%
def set_seed(seed):
    """
        ใช้สำหรับการตั้งค่า Seed Environment เพื่อให้ผลลัพธ์สามารถ Reproduce ได้
        Arg:
            seed คือ ค่า Integer สำหรับกำหนด Seed
    """
    tf.random.set_seed(seed)
    tf.config.experimental.enable_op_determinism()
    keras.utils.set_random_seed(seed)

    np.random.seed(seed)
    rd.seed(seed)

    os.environ["PYTHONHASHSEED"] = str(seed)
    os.environ["TF_DETERMINISTIC_OPS"] = "1"

    print(f"The seed number has been set at {seed}")

# %%
SEED = 42
set_seed(SEED)
# Out:
# The seed number has been set at 42

# %% [markdown]
# ## **Section 1: Preparing the directory for dataset**

# %% [markdown]
# ### **In G-Drive Directory**

# %%
DRIVE_DIR = "/content/drive/MyDrive/SWU/Older/Year3/CP461/mainProject" # Drive Directory
ASSETS_PATH = f"{DRIVE_DIR}/assets" # Assets Path
ASSETS_VISUALIZE_IMG_PATH = f"{ASSETS_PATH}/images" # Visualize Image Assets Path
DATASET_ZIP_PATH = f"{DRIVE_DIR}/datasets/ham10000Dataset"
OVER_DATASET_ZIP_PATH = f"{DRIVE_DIR}/datasets/ham10000DatasetOversampling"
INDEX_PATH = f"{DRIVE_DIR}/datasets/indexSetting"

# %%
# Setting font
fm.fontManager.addfont(f"{ASSETS_PATH}/fonts/OPTITimes-Roman.otf")
font_prop = fm.FontProperties(fname=f"{ASSETS_PATH}/fonts/OPTITimes-Roman.otf")
font_name = font_prop.get_name()
plt.rcParams["font.family"] = font_name

# %% [markdown]
# ### **In Runtime Directory**

# %%
KAGGLE_BASE_DIR = kagglehub.dataset_download("kmader/skin-cancer-mnist-ham10000")
print("Path to dataset files:", KAGGLE_BASE_DIR)
# Out:
# Using Colab cache for faster access to the 'skin-cancer-mnist-ham10000' dataset.
# Path to dataset files: /kaggle/input/skin-cancer-mnist-ham10000

# %%
METADATA_PATH = f"{KAGGLE_BASE_DIR}/HAM10000_metadata.csv"
IMAGE_PART_ONE = f"{KAGGLE_BASE_DIR}/HAM10000_images_part_1"
IMAGE_PART_TWO = f"{KAGGLE_BASE_DIR}/HAM10000_images_part_2"

# %%
IMAGE_PART_ONE_PATH = glob.glob(os.path.join(IMAGE_PART_ONE, "*.jpg"))
IMAGE_PART_TWO_PATH = glob.glob(os.path.join(IMAGE_PART_TWO, "*.jpg"))
MERGE_IMAGES = IMAGE_PART_ONE_PATH + IMAGE_PART_TWO_PATH

# %%
paths_dict = {os.path.basename(x).split(".")[0] : x for x in MERGE_IMAGES}
print(f"Number of dictionary elements: {len(paths_dict)}")
# Out:
# Number of dictionary elements: 10015

# %%
BASE_DATASET_DIR = "/content/ham10000Dataset"
OVER_DATASET_DIR = "/content/ham10000DatasetOversampling"

# %% [markdown]
# ##**Section 2: Exploratory Data Analysis (EDA)**

# %% [markdown]
# ### **Read metadata**

# %%
metadata = pd.read_csv(METADATA_PATH)
metadata
# Out:
#          lesion_id      image_id     dx dx_type   age     sex localization
# 0      HAM_0000118  ISIC_0027419    bkl   histo  80.0    male        scalp
# 1      HAM_0000118  ISIC_0025030    bkl   histo  80.0    male        scalp
# 2      HAM_0002730  ISIC_0026769    bkl   histo  80.0    male        scalp
# 3      HAM_0002730  ISIC_0025661    bkl   histo  80.0    male        scalp
# 4      HAM_0001466  ISIC_0031633    bkl   histo  75.0    male          ear
# ...            ...           ...    ...     ...   ...     ...          ...
# 10010  HAM_0002867  ISIC_0033084  akiec   histo  40.0    male      abdomen
# 10011  HAM_0002867  ISIC_0033550  akiec   histo  40.0    male      abdomen
# 10012  HAM_0002867  ISIC_0033536  akiec   histo  40.0    male      abdomen
# 10013  HAM_0000239  ISIC_0032854  akiec   histo  80.0    male         face
# 10014  HAM_0003521  ISIC_0032258    mel   histo  70.0  female         back
#
# [10015 rows x 7 columns]

# %% [markdown]
# ### **Mapping imagepath, full label and class index**

# %%
lesion_type_dict = {
    "akiec": "Actinic keratoses",
    "bcc": "Basal cell carcinoma",
    "bkl": "Benign keratosis-like lesions",
    "df": "Dermatofibroma",
    "mel": "Melanoma",
    "nv": "Melanocytic nevi",
    "vasc": "Vascular lesions"
} # เพื่อให้ลำดับ Index เหมือนตอน Train โมเดล

lesion_type_mapping = {v: k for k, v in enumerate(lesion_type_dict.values())}

metadata["filepaths"] = metadata["image_id"].map(paths_dict.get)
metadata["cell_type"] = metadata["dx"].map(lesion_type_dict.get)
metadata["cell_type"] = pd.Categorical(
    metadata["cell_type"],
    categories=[lesion_type_dict[k] for k in lesion_type_dict.keys()],
    ordered=True
)
metadata["cell_type_idx"] = metadata["cell_type"].cat.codes

metadata
# Out:
#          lesion_id      image_id     dx dx_type   age     sex localization  \
# 0      HAM_0000118  ISIC_0027419    bkl   histo  80.0    male        scalp
# 1      HAM_0000118  ISIC_0025030    bkl   histo  80.0    male        scalp
# 2      HAM_0002730  ISIC_0026769    bkl   histo  80.0    male        scalp
# 3      HAM_0002730  ISIC_0025661    bkl   histo  80.0    male        scalp
# 4      HAM_0001466  ISIC_0031633    bkl   histo  75.0    male          ear
# ...            ...           ...    ...     ...   ...     ...          ...
# 10010  HAM_0002867  ISIC_0033084  akiec   histo  40.0    male      abdomen
# 10011  HAM_0002867  ISIC_0033550  akiec   histo  40.0    male      abdomen
# 10012  HAM_0002867  ISIC_0033536  akiec   histo  40.0    male      abdomen
# 10013  HAM_0000239  ISIC_0032854  akiec   histo  80.0    male         face
# 10014  HAM_0003521  ISIC_0032258    mel   histo  70.0  female         back
#
#                                                filepaths  \
# 0      /kaggle/input/skin-cancer-mnist-ham10000/HAM10...
# 1      /kaggle/input/skin-cancer-mnist-ham10000/HAM10...
# 2      /kaggle/input/skin-cancer-mnist-ham10000/HAM10...
# 3      /kaggle/input/skin-cancer-mnist-ham10000/HAM10...
# 4      /kaggle/input/skin-cancer-mnist-ham10000/HAM10...
# ...                                                  ...
# 10010  /kaggle/input/skin-cancer-mnist-ham10000/HAM10...
# 10011  /kaggle/input/skin-cancer-mnist-ham10000/HAM10...
# 10012  /kaggle/input/skin-cancer-mnist-ham10000/HAM10...
# 10013  /kaggle/input/skin-cancer-mnist-ham10000/HAM10...
# 10014  /kaggle/input/skin-cancer-mnist-ham10000/HAM10...
#
#                            cell_type  cell_type_idx
# 0      Benign keratosis-like lesions              2
# 1      Benign keratosis-like lesions              2
# 2      Benign keratosis-like lesions              2
# 3      Benign keratosis-like lesions              2
# 4      Benign keratosis-like lesions              2
# ...                              ...            ...
# 10010              Actinic keratoses              0
# 10011              Actinic keratoses              0
# 10012              Actinic keratoses              0
# 10013              Actinic keratoses              0
# 10014                       Melanoma              4
#
# [10015 rows x 10 columns]

# %% [markdown]
# ### **Handle missing value for age column**

# %%
print("Metadata before cleaning detail")
print("-------------------------------------------")
print(f"Shape of metadata: {metadata.shape}")
print(f"Row of metadata: {metadata.shape[0]}")
print(f"Column of metadata: {metadata.shape[1]}")
print("-------------------------------------------")
print("Check missing value")
print("-------------------------------------------")
print(metadata.isnull().sum())
print("-------------------------------------------")
print("Check data type")
print("-------------------------------------------")
print(metadata.dtypes)
print("Check duplicate value")
print("-------------------------------------------")
print(f"Duplicate value count : {metadata.duplicated().sum()}")
# Out:
# Metadata before cleaning detail
# -------------------------------------------
# Shape of metadata: (10015, 10)
# Row of metadata: 10015
# Column of metadata: 10
# -------------------------------------------
# Check missing value
# -------------------------------------------
# lesion_id         0
# image_id          0
# dx                0
# dx_type           0
# age              57
# sex               0
# localization      0
# filepaths         0
# cell_type         0
# cell_type_idx     0
# dtype: int64
# -------------------------------------------
# Check data type
# -------------------------------------------
# lesion_id          object
# image_id           object
# dx                 object
# dx_type            object
# age               float64
# sex                object
# localization       object
# filepaths          object
# cell_type        category
# cell_type_idx        int8
# dtype: object
# Check duplicate value
# -------------------------------------------
# Duplicate value count : 0

# %%
msno.matrix(metadata)
# Out:
# <Axes: >

# %%
print("Metadata age describe")
print("-------------------------------------------")
print(metadata["age"].describe())
print("Metadata age median")
print("-------------------------------------------")
print(f"Age median: {metadata['age'].median()}")
# Out:
# Metadata age describe
# -------------------------------------------
# count    9958.000000
# mean       51.863828
# std        16.968614
# min         0.000000
# 25%        40.000000
# 50%        50.000000
# 75%        65.000000
# max        85.000000
# Name: age, dtype: float64
# Metadata age median
# -------------------------------------------
# Age median: 50.0

# %%
clean_df = metadata.copy()

# %%
age_median = clean_df["age"].median()
clean_df["age"] = clean_df["age"].fillna(age_median) # แทนที่ค่า NaN ด้วยค่ามัธยฐานของอายุ

print("Check missing value")
print("-------------------------------------------")
print(clean_df.isnull().sum())
print("-------------------------------------------")
# Out:
# Check missing value
# -------------------------------------------
# lesion_id        0
# image_id         0
# dx               0
# dx_type          0
# age              0
# sex              0
# localization     0
# filepaths        0
# cell_type        0
# cell_type_idx    0
# dtype: int64
# -------------------------------------------

# %%
msno.matrix(clean_df)
# Out:
# <Axes: >

# %%
print("Recheck class index and cell type")
clean_df[["dx", "cell_type", "cell_type_idx"]].drop_duplicates().sort_values("cell_type_idx").reset_index(drop=True)
# Out:
# Recheck class index and cell type
#       dx                      cell_type  cell_type_idx
# 0  akiec              Actinic keratoses              0
# 1    bcc           Basal cell carcinoma              1
# 2    bkl  Benign keratosis-like lesions              2
# 3     df                 Dermatofibroma              3
# 4    mel                       Melanoma              4
# 5     nv               Melanocytic nevi              5
# 6   vasc               Vascular lesions              6

# %% [markdown]
# ### **Univariate EDA**

# %%
def plot_univariate_distributions(df, save_path=None, fontsize=20):
    """
    ฟังก์ชันนี้ใช้สร้างกราฟแสดงการแจกแจงตัวแปรเดี่ยว (Univariate Distributions)
    จาก DataFrame ที่มีคอลัมน์ ['age', 'sex', 'dx_type', 'localization']

    Args:
        df (DataFrame): ข้อมูลที่ต้องการวิเคราะห์ โดยต้องมีคอลัมน์ 'age', 'sex', 'dx_type', 'localization'
        save_path (str, optional): ถ้าระบุ จะบันทึกภาพกราฟเป็นไฟล์ PNG และ SVG
        fontsize (int, optional): ขนาดตัวอักษรฐานสำหรับ Label และ Title (default=20)
    """
    plt.rcParams['axes.titlesize'] = fontsize
    plt.rcParams['axes.labelsize'] = fontsize * 0.85
    plt.rcParams['xtick.labelsize'] = fontsize * 0.75
    plt.rcParams['ytick.labelsize'] = fontsize * 0.75

    fig, axes = plt.subplots(2, 2, figsize=(18, 14))
    sns.despine(left=True)

    # ---- [0, 0] Age Distribution (KDE) ----
    sns.kdeplot(data=df, x="age", fill=True, color="skyblue", ax=axes[0, 0])
    axes[0, 0].set_xlabel("Age")
    axes[0, 0].set_title("Age Distribution", fontsize=fontsize)

    # ---- [0, 1] Gender Distribution ----
    sns.countplot(data=df, x="sex", hue="sex", palette="pastel", legend=False, ax=axes[0, 1])
    axes[0, 1].set_xlabel("Gender")
    axes[0, 1].set_ylabel("Count")
    axes[0, 1].set_title("Gender Distribution", fontsize=fontsize)
    axes[0, 1].tick_params(axis='x', rotation=30)

    # ---- [1, 0] Diagnosis Test Type ----
    sns.countplot(data=df, x="dx_type", hue="dx_type", palette="muted", legend=False, ax=axes[1, 0])
    axes[1, 0].set_xlabel("Diagnosis Test Type")
    axes[1, 0].set_ylabel("Count")
    axes[1, 0].set_title("Diagnosis Test Type Distribution", fontsize=fontsize)
    axes[1, 0].tick_params(axis='x', rotation=30)

    # ---- [1, 1] Lesion Localization ----
    sns.countplot(data=df, x="localization", hue="localization", palette="Set2", legend=False, ax=axes[1, 1])
    axes[1, 1].set_xlabel("Localization Area")
    axes[1, 1].set_ylabel("Count")
    axes[1, 1].set_title("Localization Area Distribution", fontsize=fontsize)
    axes[1, 1].tick_params(axis='x', rotation=90)

    plt.tight_layout(rect=[0, 0, 1, 0.96])
    fig.suptitle("Univariate Distributions", fontsize=fontsize * 1.2)

    if save_path:
        plt.savefig(f"{save_path}.png", format="png", dpi=300, bbox_inches="tight")
        plt.savefig(f"{save_path}.svg", format="svg", bbox_inches="tight")

    plt.show()

# %%
plot_univariate_distributions(
    df=clean_df,
    save_path=f"{ASSETS_VISUALIZE_IMG_PATH}/univariate_distributions",
    fontsize=20
)

# %% [markdown]
# ### **Bivariate EDA**

# %%
def plot_age_boxplots(df, fontsize=20, save_path=None):
    """
    ฟังก์ชันนี้ใช้สร้างกราฟกล่อง (Boxplot) แสดงการกระจายอายุ
    โดยเปรียบเทียบตามเพศ (sex) และประเภทรอยโรค (dx)

    Args:
        df (DataFrame): ข้อมูลที่ต้องมีคอลัมน์ 'age', 'sex', 'dx'
        fontsize (int, optional): ขนาดตัวอักษรฐานสำหรับ labels และ titles
        save_path (str, optional): ถ้าระบุ จะบันทึกกราฟเป็นไฟล์ PNG และ SVG
    """
    plt.rcParams['axes.titlesize'] = fontsize
    plt.rcParams['axes.labelsize'] = fontsize * 0.85
    plt.rcParams['xtick.labelsize'] = fontsize * 0.75
    plt.rcParams['ytick.labelsize'] = fontsize * 0.75

    fig, axes = plt.subplots(1, 2, figsize=(16, 8))
    sns.despine(left=True)

    # Gender vs Age
    sns.boxplot(x="sex", y="age", data=df, hue="sex", palette="pastel", legend=False, ax=axes[0])
    axes[0].set_xlabel("Gender")
    axes[0].set_ylabel("Age")
    axes[0].set_title("Gender vs Age Boxplot", fontsize=fontsize-2)
    axes[0].tick_params(axis="x", rotation=30)

    # Lesion Type vs Age
    sns.boxplot(x="dx", y="age", data=df, hue="dx", palette="muted", legend=False, ax=axes[1])
    axes[1].set_xlabel("Lesion Type")
    axes[1].set_ylabel("Age")
    axes[1].set_title("Lesion Type vs Age Boxplot", fontsize=fontsize-2)
    axes[1].tick_params(axis="x", rotation=30)

    plt.tight_layout(rect=[0, 0, 1, 0.96])
    fig.suptitle("Bivariate Distribution", fontsize=fontsize * 1.1)

    if save_path:
        plt.savefig(f"{save_path}.png", dpi=300, bbox_inches="tight")
        plt.savefig(f"{save_path}.svg", bbox_inches="tight")

    plt.show()

# %%
plot_age_boxplots(
    df=clean_df,
    fontsize=20,
    save_path=f"{ASSETS_VISUALIZE_IMG_PATH}/bivariate_distributions"
)

# %%
def plot_bivariate_distributions(df, save_path=None, fontsize=20):
    """
    แสดงความสัมพันธ์ระหว่าง metadata (age, sex, localization) กับ target (dx)
    ในรูปแบบ 1 แถว 3 คอลัมน์
    """
    plt.rcParams['axes.titlesize'] = fontsize
    plt.rcParams['axes.labelsize'] = fontsize * 0.85
    plt.rcParams['xtick.labelsize'] = fontsize * 0.75
    plt.rcParams['ytick.labelsize'] = fontsize * 0.75

    fig, axes = plt.subplots(1, 3, figsize=(26, 7))
    sns.despine(left=True)

    # ---- [0] Age vs DX (Boxplot) ----
    sns.boxplot(data=df, x="dx", y="age", hue="dx", palette="coolwarm", legend=False, ax=axes[0])
    axes[0].set_title("Age vs Diagnosis (dx)")
    axes[0].set_xlabel("Diagnosis")
    axes[0].set_ylabel("Age")
    axes[0].tick_params(axis='x', rotation=45)

    # ---- [1] Sex vs DX (Countplot) ----
    sns.countplot(data=df, x="dx", hue="sex", palette="pastel", ax=axes[1])
    axes[1].set_title("Gender Distribution by Diagnosis")
    axes[1].set_xlabel("Diagnosis")
    axes[1].set_ylabel("Count")
    axes[1].tick_params(axis='x', rotation=45)
    axes[1].legend(title="Gender", loc="upper right", fontsize=fontsize * 0.6)

    # ---- [2] Localization vs DX (Countplot) ----
    sns.countplot(data=df, x="dx", hue="localization", palette="Set2", ax=axes[2])
    axes[2].set_title("Localization Distribution by Diagnosis")
    axes[2].set_xlabel("Diagnosis")
    axes[2].set_ylabel("Count")
    axes[2].tick_params(axis='x', rotation=45)
    axes[2].legend(title="Localization", bbox_to_anchor=(1.05, 1), loc="upper left", fontsize=fontsize * 0.6)

    # ---- Layout ----
    plt.tight_layout(rect=[0, 0, 1, 0.95])
    fig.suptitle("Bivariate Distributions: Age, Sex, Localization vs DX", fontsize=fontsize * 1.2)

    if save_path:
        plt.savefig(f"{save_path}.png", format="png", dpi=300, bbox_inches="tight")
        plt.savefig(f"{save_path}.svg", format="svg", bbox_inches="tight")

    plt.show()

# %%
plot_bivariate_distributions(
    df=clean_df,
    save_path=f"{ASSETS_VISUALIZE_IMG_PATH}/bivariate_distributions_2",
    fontsize=20
)

# %% [markdown]
# ### **Handle unknown value for gender column**

# %%
print("Gender feature before cleaning:")
print(clean_df["sex"].value_counts())
# Out:
# Gender feature before cleaning:
# sex
# male       5406
# female     4552
# unknown      57
# Name: count, dtype: int64

# %%
clean_df = clean_df[clean_df["sex"] != "unknown"]
print(f"Gender feature after cleaning:")
print(clean_df["sex"].value_counts())
# Out:
# Gender feature after cleaning:
# sex
# male      5406
# female    4552
# Name: count, dtype: int64

# %% [markdown]
# ### **Handle unknown value for localization area column**

# %%
print(f"Localization feature before cleaning:")
print(clean_df["localization"].value_counts())
# Out:
# Localization feature before cleaning:
# localization
# back               2190
# lower extremity    2077
# trunk              1401
# upper extremity    1118
# abdomen            1020
# face                745
# chest               407
# foot                316
# unknown             187
# neck                168
# scalp               128
# hand                 90
# ear                  56
# genital              48
# acral                 7
# Name: count, dtype: int64

# %%
clean_df = clean_df[clean_df["localization"] != "unknown"]
print(f"Localization feature after cleaning:")
print(clean_df["localization"].value_counts())
# Out:
# Localization feature after cleaning:
# localization
# back               2190
# lower extremity    2077
# trunk              1401
# upper extremity    1118
# abdomen            1020
# face                745
# chest               407
# foot                316
# neck                168
# scalp               128
# hand                 90
# ear                  56
# genital              48
# acral                 7
# Name: count, dtype: int64

# %% [markdown]
# ### **EDA Summary**

# %%
print("Metadata before cleaning detail")
print("-------------------------------------------")
print(f"Shape of metadata: {clean_df.shape}")
print(f"Row of metadata: {clean_df.shape[0]}")
print(f"Column of metadata: {clean_df.shape[1]}")
print("-------------------------------------------")
print("Check missing value")
print("-------------------------------------------")
print(clean_df.isnull().sum())
print("-------------------------------------------")
print("Check data type")
print("-------------------------------------------")
print(clean_df.dtypes)
print("Check duplicate value")
print("-------------------------------------------")
print(f"Duplicate value count : {clean_df.duplicated().sum()}")
# Out:
# Metadata before cleaning detail
# -------------------------------------------
# Shape of metadata: (9771, 10)
# Row of metadata: 9771
# Column of metadata: 10
# -------------------------------------------
# Check missing value
# -------------------------------------------
# lesion_id        0
# image_id         0
# dx               0
# dx_type          0
# age              0
# sex              0
# localization     0
# filepaths        0
# cell_type        0
# cell_type_idx    0
# dtype: int64
# -------------------------------------------
# Check data type
# -------------------------------------------
# lesion_id          object
# image_id           object
# dx                 object
# dx_type            object
# age               float64
# sex                object
# localization       object
# filepaths          object
# cell_type        category
# cell_type_idx        int8
# dtype: object
# Check duplicate value
# -------------------------------------------
# Duplicate value count : 0

# %% [markdown]
# ### **Export metadata after cleaning**

# %%
clean_df.to_csv(f"{INDEX_PATH}/metadata_cleaning.csv", index=False)

# %% [markdown]
# ## **Section 3: Verify the images**

# %%
process_df = clean_df.copy()
process_df
# Out:
#          lesion_id      image_id     dx dx_type   age     sex localization  \
# 0      HAM_0000118  ISIC_0027419    bkl   histo  80.0    male        scalp
# 1      HAM_0000118  ISIC_0025030    bkl   histo  80.0    male        scalp
# 2      HAM_0002730  ISIC_0026769    bkl   histo  80.0    male        scalp
# 3      HAM_0002730  ISIC_0025661    bkl   histo  80.0    male        scalp
# 4      HAM_0001466  ISIC_0031633    bkl   histo  75.0    male          ear
# ...            ...           ...    ...     ...   ...     ...          ...
# 10010  HAM_0002867  ISIC_0033084  akiec   histo  40.0    male      abdomen
# 10011  HAM_0002867  ISIC_0033550  akiec   histo  40.0    male      abdomen
# 10012  HAM_0002867  ISIC_0033536  akiec   histo  40.0    male      abdomen
# 10013  HAM_0000239  ISIC_0032854  akiec   histo  80.0    male         face
# 10014  HAM_0003521  ISIC_0032258    mel   histo  70.0  female         back
#
#                                                filepaths  \
# 0      /kaggle/input/skin-cancer-mnist-ham10000/HAM10...
# 1      /kaggle/input/skin-cancer-mnist-ham10000/HAM10...
# 2      /kaggle/input/skin-cancer-mnist-ham10000/HAM10...
# 3      /kaggle/input/skin-cancer-mnist-ham10000/HAM10...
# 4      /kaggle/input/skin-cancer-mnist-ham10000/HAM10...
# ...                                                  ...
# 10010  /kaggle/input/skin-cancer-mnist-ham10000/HAM10...
# 10011  /kaggle/input/skin-cancer-mnist-ham10000/HAM10...
# 10012  /kaggle/input/skin-cancer-mnist-ham10000/HAM10...
# 10013  /kaggle/input/skin-cancer-mnist-ham10000/HAM10...
# 10014  /kaggle/input/skin-cancer-mnist-ham10000/HAM10...
#
#                            cell_type  cell_type_idx
# 0      Benign keratosis-like lesions              2
# 1      Benign keratosis-like lesions              2
# 2      Benign keratosis-like lesions              2
# 3      Benign keratosis-like lesions              2
# 4      Benign keratosis-like lesions              2
# ...                              ...            ...
# 10010              Actinic keratoses              0
# 10011              Actinic keratoses              0
# 10012              Actinic keratoses              0
# 10013              Actinic keratoses              0
# 10014                       Melanoma              4
#
# [9771 rows x 10 columns]

# %%
def verify_images(df, filepaths_col):
    """
        สำหรับตรวจสอบรูปภาพ เพื่อสแกนหาว่ามีภาพที่เสียหรือเปิดไม่ได้หรือไม่
        Args:
            df คือ Pandas dataframe ที่มี Column Filepaths สำหรับอ้างอิงไปยังตำแหน่งของรูปภาพ
            filepaths_col คือ ชื่อของ Column ที่เก็บตำแหน่งของรูปภาพ
        Return:
            List ที่เก็บชื่อไฟล์ที่พบปัญหา
    """
    corrupted_images = []
    filepaths = df[filepaths_col].values

    for filepath in tqdm(filepaths, desc="Verifying Images"):
        try:
            img = cv2.imread(filepath)
            if img is None:
                corrupted_images.append(filepath)
                os.remove(filepath) # ถ้าเจอภาพเสียลบออก
                print(f"Corrupted or unreadable image removed: {filepath}")
        except Exception as e:
            corrupted_images.append(filepath)
            os.remove(filepath) # ถ้าเจอภาพเสียลบออก
            print(f"Error verifying image: {filepath} - {e}")

    return corrupted_images

# %%
corrupted_images = verify_images(process_df, "filepaths")
# Out:
# Verifying Images: 100%|██████████| 9771/9771 [02:46<00:00, 58.84it/s]

# %%
print(f"Number of corrupted images: {len(corrupted_images)}")
# Out:
# Number of corrupted images: 0

# %% [markdown]
# ## **Section 4: Split data into Train, Validation and Test**

# %% [markdown]
# **Split data into ratio train 80 validation 10 and test 10 From Original Paper**

# %%
df_train_original, df_temp = sklearn.model_selection.train_test_split(
    metadata, # แบ่งจาก Metadata ที่มีข้อมูลภาพครบ ๆ
    test_size=0.2,
    stratify=metadata["cell_type_idx"],
    random_state=SEED
)

df_val_original, df_test_original = sklearn.model_selection.train_test_split(
    df_temp,
    test_size=0.5,
    stratify=df_temp["cell_type_idx"],
    random_state=SEED
)

# %%
total_original_images = len(metadata)

print(f"Total original images: {total_original_images}")
print(f"Train original images: {len(df_train_original)} ({len(df_train_original)/total_original_images*100:.2f}%)")
print(f"Val original images:   {len(df_val_original)} ({len(df_val_original)/total_original_images*100:.2f}%)")
print(f"Test original images:  {len(df_test_original)} ({len(df_test_original)/total_original_images*100:.2f}%)")
print(f"Sum original images:   {len(df_train_original) + len(df_val_original) + len(df_test_original)}")
print("-" * 30)
# Out:
# Total original images: 10015
# Train original images: 8012 (80.00%)
# Val original images:   1001 (10.00%)
# Test original images:  1002 (10.00%)
# Sum original images:   10015
# ------------------------------

# %% [markdown]
# **Split data into ratio train 80 validation 10 and test 10 Based on Valid Metadata**

# %%
# หา Unique ตัวแบ่งกลุ่มที่จะ Split ข้อมูลโดยที่ไม่ซ้ำ
lesion_id = process_df.drop_duplicates(subset="lesion_id")
lesion_id = lesion_id[["lesion_id", "cell_type_idx"]]
print(f"Total images: {len(lesion_id)}")
print(f"Total unique lesions: {len(lesion_id)}")
# Out:
# Total images: 7263
# Total unique lesions: 7263

# %%
train_lesions, temp_lesions = sklearn.model_selection.train_test_split(
    lesion_id,
    test_size=0.2,
    stratify=lesion_id["cell_type_idx"],
    random_state=SEED
)

val_lesions, test_lesions = sklearn.model_selection.train_test_split(
    temp_lesions,
    test_size=0.5,
    stratify=temp_lesions["cell_type_idx"],
    random_state=SEED
)

print(f"Total lesions: {len(lesion_id)}")
print(f"Train lesions: {len(train_lesions)}")
print(f"Val lesions:   {len(val_lesions)}")
print(f"Test lesions:  {len(test_lesions)}")
# Out:
# Total lesions: 7263
# Train lesions: 5810
# Val lesions:   726
# Test lesions:  727

# %%
train_ids = set(train_lesions["lesion_id"])
val_ids = set(val_lesions["lesion_id"])
test_ids = set(test_lesions["lesion_id"])

# %%
df_train = process_df[process_df["lesion_id"].isin(train_ids)].copy()
df_val = process_df[process_df["lesion_id"].isin(val_ids)].copy()
df_test = process_df[process_df["lesion_id"].isin(test_ids)].copy()

# %%
total_images = len(clean_df)

print(f"Total original images: {total_images}")
print(f"Train images: {len(df_train)} ({len(df_train)/total_images*100:.2f}%)")
print(f"Val images:   {len(df_val)} ({len(df_val)/total_images*100:.2f}%)")
print(f"Test images:  {len(df_test)} ({len(df_test)/total_images*100:.2f}%)")
print(f"Sum images:   {len(df_train) + len(df_val) + len(df_test)}")
print("-" * 30)

train_val_overlap = np.intersect1d(df_train["lesion_id"], df_val["lesion_id"])
train_test_overlap = np.intersect1d(df_train["lesion_id"], df_test["lesion_id"])
val_test_overlap = np.intersect1d(df_val["lesion_id"], df_test["lesion_id"])

# เพื่อรับประกันว่าข้อมูลจะไม่รั่วไหล
print(f"Overlap Train-Val: {len(train_val_overlap)}")
print(f"Overlap Train-Test: {len(train_test_overlap)}")
print(f"Overlap Val-Test: {len(val_test_overlap)}")
# Out:
# Total original images: 9771
# Train images: 7832 (80.16%)
# Val images:   984 (10.07%)
# Test images:  955 (9.77%)
# Sum images:   9771
# ------------------------------
# Overlap Train-Val: 0
# Overlap Train-Test: 0
# Overlap Val-Test: 0

# %% [markdown]
# ## **Section 5: Create dataset tree directory**

# %%
def merge_directory(df_train, df_val, df_test,
                    filepaths_col, labels_col,
                    dest_dir, zip_dir=None):
    """
        สำหรับการ Merge source directories ตั้งแต่ 2 แหล่งขึ้นไป รวมเป็น 1 เดียว พร้อมกับสร้าง Sub folder ตาม Label ของแต่ละภาพ
        Structure folder:
            Main folder
            |
            |__train
               |_classA
                    |_IMG_1.jpg
               |_classB
                    |_IMG_2.jpg
            |__val
               |_classA
                    |_IMG_1.jpg
               |_classB
                    |_IMG_2.jpg
            |__test
               |_classA
                    |_IMG_1.jpg
               |_classB
                    |_IMG_2.jpg

        Args:
            df_train, df_val, df_test : DataFrame ของแต่ละชุดข้อมูล
            filepaths_col คือ ชื่อของ Column ที่เก็บตำแหน่งของรูปภาพ
            labels_col คือ ชื่อของ Column ที่เก็บ Label ของภาพ
            dest_dir คือ directory ปลายทาง
            zip_dir (optional) รับค่าเป็น Path ไฟล์เพื่อ zip ไฟล์เก็บไว้
    """
    os.makedirs(dest_dir, exist_ok=True)
    print(f"Destination directory has been created at: {dest_dir}")

    datasets = {
        "train": df_train,
        "val": df_val,
        "test": df_test
    }

    for split_name, df in datasets.items():
        print(f"\nProcessing {split_name} set ({len(df)} images)...")

        split_dir = os.path.join(dest_dir, split_name)
        os.makedirs(split_dir, exist_ok=True)

        # สร้าง subfolder ตาม label
        labels = df[labels_col].unique().tolist()
        for label in labels:
            label_dir = os.path.join(split_dir, label)
            os.makedirs(label_dir, exist_ok=True)

        # คัดลอกไฟล์
        filepaths = df[filepaths_col].values
        image_labels = df[labels_col].values

        for src_path, image_label in tqdm(
            zip(filepaths, image_labels),
            total=len(df),
            desc=f"Copying {split_name}"
        ):
            filename = os.path.basename(src_path)
            dst_path = os.path.join(split_dir, image_label, filename)
            shutil.copyfile(src_path, dst_path)

    if zip_dir:
        shutil.make_archive(zip_dir, "zip", dest_dir)
        print(f"Zip file has been created at: {zip_dir}")

# %%
def update_path(df_train, df_val, df_test,
                base_path, filepaths_col, labels_col):
    """
    ฟังก์ชันนี้ใช้อัปเดตเส้นทางไฟล์ (file path) ใน DataFrame
    โดยรวม base_path, label และชื่อไฟล์เข้าด้วยกัน

    Args:
        df_train, df_val, df_test : DataFrame ของแต่ละชุดข้อมูล
        base_path (str): โฟลเดอร์หลักของไฟล์
        filepaths_col (str): ชื่อคอลัมน์ที่เก็บ path ของไฟล์เดิม
        labels_col (str): ชื่อคอลัมน์ที่เก็บ label ของไฟล์

    Returns:
        (df_train, df_val, df_test): DataFrame ทั้งสามชุดที่อัปเดต path แล้ว
    """
    def update_single(df, split_name):
        split_path = os.path.join(base_path, split_name)
        filenames = df[filepaths_col].apply(os.path.basename)
        labels = df[labels_col]
        df[filepaths_col] = split_path + "/" + labels + "/" + filenames
        return df

    df_train = update_single(df_train.copy(), "train")
    df_val = update_single(df_val.copy(), "val")
    df_test = update_single(df_test.copy(), "test")

    print(f"Updated paths for train ({len(df_train)}), val ({len(df_val)}), test ({len(df_test)})")
    return df_train, df_val, df_test

# %%
merge_directory(
    df_train=df_train_original,
    df_val=df_val_original,
    df_test=df_test_original,
    filepaths_col="filepaths",
    labels_col="dx",
    dest_dir=BASE_DATASET_DIR,
    zip_dir=DATASET_ZIP_PATH
)
# Out:
# Destination directory has been created at: /content/ham10000Dataset
#
# Processing train set (8012 images)...
# Copying train: 100%|██████████| 8012/8012 [01:45<00:00, 76.14it/s]
# Processing val set (1001 images)...
# Copying val: 100%|██████████| 1001/1001 [00:12<00:00, 80.22it/s]
# Processing test set (1002 images)...
# Copying test: 100%|██████████| 1002/1002 [00:13<00:00, 73.63it/s]
# Zip file has been created at: /content/drive/MyDrive/CP461/mainProject/datasets/ham10000Dataset

# %%
df_train_original, df_val_original, df_test_original = update_path(
    df_train=df_train_original,
    df_val=df_val_original,
    df_test=df_test_original,
    base_path=BASE_DATASET_DIR,
    filepaths_col="filepaths",
    labels_col="dx"
) # Rename path to match new path
# Out:
# Updated paths for train (8012), val (1001), test (1002)

# %%
df_train_original.to_csv(f"{INDEX_PATH}/metadata_train_original.csv", index=False)
df_val_original.to_csv(f"{INDEX_PATH}/metadata_val_original.csv", index=False)
df_test_original.to_csv(f"{INDEX_PATH}/metadata_test_original.csv", index=False)

# %% [markdown]
# ## **Section 6: Visualization images**

# %%
def plot_distribution(df, labels_col, save_path=None, fontsize=18, title="Class Distribution"):
    """
        แสดงจำนวนรูปภาพในแต่ละ Class แบบ Bar plot
        Args:
            df คือ Pandas dataframe ที่มี Column Label สำหรับอ้างอิง Label ของภาพ
            labels_col คือ ชื่อของ Column ที่เก็บ Label
            save_path (optional) หากใส่ filepath แบบ String จะทำการ Save Image เป็น .png และ .svg
            fontsize คือ ขนาด font (default = 18)
            title คือ ชื่อหัวข้อ
    """
    class_counts = df[labels_col].value_counts().reset_index()
    class_counts.columns = [labels_col, "count"]

    classes = sorted(df[labels_col].unique())
    palette = sns.color_palette("viridis", n_colors=len(classes))
    class_palette = {cls: palette[i] for i, cls in enumerate(classes)}

    plt.figure(figsize=(12, 8))
    sns.barplot(
        x=labels_col,
        y="count",
        data=class_counts,
        hue=labels_col,
        palette=class_palette,
        dodge=False,
        legend=False,
        order=classes
    )

    plt.title(title, fontsize=fontsize+2, weight="bold")
    plt.xlabel("Classes", fontsize=fontsize)
    plt.ylabel("Number of Images", fontsize=fontsize)
    plt.xticks(rotation=45, ha="right", fontsize=fontsize-2)
    plt.yticks(fontsize=fontsize-2)

    for i, count in enumerate(class_counts.set_index(labels_col).loc[classes]["count"]):
        plt.text(i, count, str(count), ha="center", va="bottom", fontsize=fontsize-2)

    plt.tight_layout()

    if save_path:
        plt.savefig(f"{save_path}.png", format="png", dpi=300, bbox_inches="tight")
        plt.savefig(f"{save_path}.svg", format="svg", bbox_inches="tight")

    plt.show()

# %%
'''def visualize_image_by_class(df, filepaths_col, labels_col, labels_dict, save_path=None, fontsize=20, title="HAM10000 Dataset", num_images=7):
    """
        แสดงรูปภาพ Sample โดยแยกตาม Label ในแต่ละ Row
        Args:
            df คือ Pandas dataframe ที่มี Column Filepaths สำหรับอ้างอิงไปยังตำแหน่งของรูปภาพ และ Column Label สำหรับอ้างอิง Label ของภาพ
            filepaths_col คือ ชื่อของ Column ที่เก็บตำแหน่งของรูปภาพ
            labels_col คือ ชื่อของ Column ที่เก็บ Label ของภาพ
            labels_dict คือ dict ที่เก็บ key เป็นชื่อย่อของ Label และ value เป็นชื่อเต็มของ Label
            save_path (optional) หากใส่ filepath แบบ String จะทำการ Save Image เป็น .png และ .svg
            fontsize คือ ขนาด font (default = 18)
            title คือ ชื่อหัวข้อ
            num_images คือ จำนวนรูปภาพที่ต้องการแสดงในแต่ละแถว
    """
    unique_labels = df[labels_col].unique()
    num_classes = len(unique_labels)

    plt.figure(figsize=(num_images * 3, num_classes * 3))

    for i, label in enumerate(unique_labels):
        label_df = df[df[labels_col] == label]
        sample_paths = label_df[filepaths_col].sample(
            n=min(num_images, len(label_df)),
            random_state=SEED
        ).tolist()

        for j, filepath in enumerate(sample_paths):
            ax = plt.subplot(num_classes, num_images, i * num_images + j + 1)
            img = cv2.imread(filepath)
            img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
            plt.imshow(img)
            plt.axis("off")

            if j == 0:
                fullname = labels_dict.get(label, label)
                ax.set_title(f"{fullname} ({label})", loc="left", fontsize=fontsize, pad=10)

    plt.suptitle(title, fontsize=fontsize+2, weight="bold")
    plt.tight_layout()
    plt.subplots_adjust(hspace=-0.05)

    if save_path:
        plt.savefig(f"{save_path}.png", format="png", dpi=300, bbox_inches="tight")
        plt.savefig(f"{save_path}.svg", format="svg", bbox_inches="tight")

    plt.show()'''

# %%
# visualize images
def vis_images(df, filepaths_col, label_col, n_rows=2, n_cols=5,
               target_size=(224, 224), figsize=(15, 6), fontsize=14, title=None, save_path=None):

    total_slots = n_rows * n_cols
    subset = df.iloc[:total_slots]
    total_images = len(subset)

    fig = plt.figure(figsize=figsize)

    if title:
        fig.suptitle(title, fontsize=fontsize + 2, fontweight='bold', y=0.97)

    img_width = 0.15
    img_height = 0.35
    spacing = 0.02

    for r in range(n_rows):
        row_start = r * n_cols
        row_end = min(row_start + n_cols, total_images)
        row_items = row_end - row_start

        if row_items <= 0:
            break

        total_row_width = row_items * img_width + (row_items - 1) * spacing
        start_x = (1.0 - total_row_width) / 2

        y_pos = 0.55 - r * 0.45

        for c in range(row_items):
            idx = row_start + c
            row = subset.iloc[idx]
            img_path = pathlib.Path(row[filepaths_col])

            ax = fig.add_axes([
                start_x + c * (img_width + spacing),
                y_pos,
                img_width,
                img_height
            ])

            img = Image.open(img_path).convert('RGB').resize(target_size)
            ax.imshow(img)

            ax.text(
                0.5, -0.1,
                f'{row[label_col]}',
                fontsize=fontsize,
                ha='center',
                va='center',
                transform=ax.transAxes
            )

            ax.axis('off')

    if save_path:
        plt.savefig(f'{save_path}.png', dpi=300, bbox_inches='tight')
        plt.savefig(f'{save_path}.svg', bbox_inches='tight')

    plt.show()

# %%
metadata = pd.read_csv(f"{INDEX_PATH}/metadata_train_original.csv")
unique_label = (
    metadata.groupby('dx', as_index=False).sample(n=1, random_state=123)
)

vis_images(
    df=unique_label,
    filepaths_col="filepaths",
    label_col="dx",
    n_rows=2,
    n_cols=4,
    figsize=(14, 6),
    fontsize=14
)

# %%
df_train_original = pd.read_csv(f"{INDEX_PATH}/metadata_train_original.csv")
df_val_original = pd.read_csv(f"{INDEX_PATH}/metadata_val_original.csv")
df_test_original = pd.read_csv(f"{INDEX_PATH}/metadata_test_original.csv")
df_combined = pd.concat([df_train_original, df_val_original, df_test_original], ignore_index=True)

# %%
plot_distribution(
    df=df_combined,
    labels_col="dx",
    save_path=f"{ASSETS_VISUALIZE_IMG_PATH}/class_distribution",
    fontsize=20,
    title="Class Distribution Overall"
)

# %% [markdown]
# ## **Section 7: Visualization and fixed imbalanced for training data by transfrom image**

# %%
# !unzip /content/drive/MyDrive/SWU/Older/Year3/CP461/mainProject/datasets/ham10000Dataset.zip -d /content/ham10000Dataset
# Out:
# เอาต์พุตของการสตรีมมีการตัดเหลือเพียง 5000 บรรทัดสุดท้าย
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0030455.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0030406.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0031881.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0024531.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0031001.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0028637.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0032902.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0031327.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0032336.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0033818.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0028230.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0027493.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0033543.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0033242.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0024401.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0033919.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0029057.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0032530.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0028018.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0033273.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0027687.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0033427.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0028005.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0030206.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0027643.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0026186.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0025742.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0033352.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0025678.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0028402.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0027555.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0027318.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0028507.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0026715.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0034001.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0031190.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0032370.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0031493.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0032889.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0027728.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0030035.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0032749.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0027729.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0025406.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0024725.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0030111.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0027683.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0029732.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0029373.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0026858.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0028009.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0029833.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0031426.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0025242.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0033423.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0026864.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0027765.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0025686.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0026917.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0026151.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0028399.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0025170.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0026025.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0032971.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0033062.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0031854.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0031113.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0032026.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0028986.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0024768.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0025026.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0027670.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0027594.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0026699.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0025361.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0027070.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0026810.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0025398.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0033182.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0027173.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0031724.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0033101.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0032002.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0027106.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0028705.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0027228.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0032143.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0025141.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0031930.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0025501.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0031734.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0029482.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0028585.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0029493.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0028367.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0033115.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0026478.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0030656.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0025336.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0025610.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0030811.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0031014.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0032186.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0030162.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0032153.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0024510.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0032881.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0025377.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0031232.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0026832.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0026734.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0028936.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0028380.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0028684.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0027539.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0028290.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0028625.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0028193.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0029388.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0032263.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0024307.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0027723.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0031340.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0030354.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0032122.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0025158.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0027181.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0028594.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0025773.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0026261.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0032989.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0025608.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0024660.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0027813.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0025905.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0025993.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0034139.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0028119.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0033395.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0034260.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0028053.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0028624.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0029450.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0030928.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0027821.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0028891.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0028205.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0031939.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0028657.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0028843.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0031860.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0025629.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0027906.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0029714.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0028345.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0031907.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0028176.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0031402.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0028435.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0032588.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0030065.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0026597.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0027494.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0030474.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0028081.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0031382.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0032229.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0028139.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0026031.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0029661.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0025340.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0024473.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0032189.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0029106.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0024576.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0032585.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0030033.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0028001.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0024356.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0031448.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0025282.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0029581.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0030939.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0026214.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0031541.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0029488.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0025423.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0030787.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0028976.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0030895.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0029700.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0027692.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0026821.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0024541.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0030657.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0030869.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0027511.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0029620.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0032832.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0026669.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0033385.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0034081.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0033792.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0028798.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0027288.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0031525.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0026641.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0028342.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0027217.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0032659.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0025060.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0028488.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0029266.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0032354.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0025495.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0032101.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0027393.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0033727.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0031173.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0027398.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0030913.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0028996.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0025165.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0034156.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0026510.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0027800.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0026168.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0024398.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0027549.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0029529.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0031336.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0031611.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0025418.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0029712.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0029938.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0028694.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0029818.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0029441.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0032974.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0026888.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0030046.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0029616.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0030615.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0030819.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0029374.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0032255.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0027936.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0033370.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0031052.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0028416.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0029077.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0028679.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0031439.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0031717.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0032005.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0029269.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0024979.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0025538.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0025289.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0032951.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0033371.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0024908.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0028538.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0029948.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0033990.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0029093.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0030182.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0024600.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0029188.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0027565.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0029800.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0025252.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0031487.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0031559.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0027877.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0033622.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0029798.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0025287.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0028145.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0031474.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0028817.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0032412.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0027934.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0034199.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0031912.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0027197.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0026029.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0032272.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0031850.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0025213.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0024339.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0027489.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0028636.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0027768.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0033870.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0025426.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0031460.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0033338.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0028589.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0030842.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0028689.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0026185.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0025298.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0030466.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0026241.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0024686.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0025916.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0025624.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0028884.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0030079.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0027379.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0029386.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0030909.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0029484.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0031678.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0030941.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0033167.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0032706.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0031418.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0032735.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0027119.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0025159.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0025101.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0034220.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0026676.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0029411.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0029222.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0026833.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0029583.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0027551.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0032234.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0028631.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0030743.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0032674.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0029944.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0029479.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0028602.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0026784.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0025079.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0032361.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0030450.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0026177.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0033715.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0026322.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0026452.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0030210.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0033045.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0030155.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0026134.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0030325.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0026414.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0026513.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0033177.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0030184.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0028210.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0030092.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0025273.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0033954.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0031209.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0025884.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0025740.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0033921.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0027841.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0034013.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0028526.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0029925.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0031817.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0026611.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0027056.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0032176.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0025844.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0031221.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0032250.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0026470.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0029957.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0030405.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0026437.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0025308.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0031917.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0028320.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0026366.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0028895.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0034300.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0032992.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0027209.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0029191.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0033600.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0033590.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0029511.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0024754.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0025008.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0031675.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0033796.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0029566.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0024407.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0032477.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0024716.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0025503.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0024764.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0032916.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0032289.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0027530.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0024715.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0030517.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0032120.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0030502.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0031328.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0024692.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0024584.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0033009.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0033577.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0026002.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0030857.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0030520.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0029650.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0030719.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0027707.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0033190.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0026939.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0032259.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0031246.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0027082.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0030678.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0029159.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0030186.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0032231.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0027465.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0026975.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0026808.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0029904.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0033149.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0033291.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0027446.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0026346.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0026338.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0032589.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0030992.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0029734.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0032273.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0033889.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0025124.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0032671.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0033542.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0030997.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0028108.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0031059.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0027421.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0025149.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0027970.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0034164.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0025687.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0028811.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0032434.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0027170.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0032296.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0033389.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0026143.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0031606.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0024809.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0027242.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0026124.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0025695.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0030984.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0028089.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0034023.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0027078.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0026879.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0029605.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0033339.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0033112.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0027749.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0029987.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0029422.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0025051.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0032781.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0030308.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0032435.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0028117.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0033168.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0030296.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0031879.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0031667.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0028006.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0031476.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0029552.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0028674.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0026743.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0028668.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0028844.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0025525.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0024638.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0028212.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0031838.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0026210.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0032510.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0025552.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0030268.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0031180.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0025477.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0028647.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0024526.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0034128.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0029946.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0029633.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0031484.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0028159.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0032142.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0024980.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0025129.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0027010.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0027861.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0024869.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0029038.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0026529.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0030733.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0032490.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0028422.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0025458.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0026004.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0027984.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0026401.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0028244.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0031440.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0029151.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0030987.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0033100.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0028748.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0026400.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0032548.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0029736.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0029063.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0028758.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0027127.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0033341.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0030193.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0026048.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0025760.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0024847.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0024919.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0033740.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0030546.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0028605.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0024388.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0030865.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0027348.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0025401.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0028298.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0031835.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0034032.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0026962.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0030660.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0028101.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0027377.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0033510.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0030554.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0030637.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0031964.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0031020.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0026805.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0032914.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0026659.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0033793.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0029882.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0025328.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0029054.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0025918.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0025590.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0030599.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0033002.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0025365.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0032717.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0027725.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0032759.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0030353.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0029982.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0030906.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0026221.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0031690.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0033858.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0027114.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0028988.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0032150.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0029623.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0028019.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0027418.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0025403.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0030128.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0028509.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0030170.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0032056.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0028953.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0024599.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0025463.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0026969.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0030880.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0031458.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0027931.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0030815.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0026682.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0032780.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0025999.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0028368.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0027902.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0026449.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0029983.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0028397.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0025684.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0024316.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0025943.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0030178.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0031936.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0028191.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0025896.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0025788.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0032785.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0026585.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0026348.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0028805.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0028882.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0025968.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0030045.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0028513.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0027331.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0028160.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0026756.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0031566.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0029637.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0031736.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0032383.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0030069.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0029821.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0031562.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0028070.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0026550.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0028903.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0033935.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0024591.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0032467.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0033712.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0032783.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0025134.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0026005.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0029595.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0026987.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0027366.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0029179.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0027951.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0029517.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0029773.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0028417.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0029219.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0030917.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0030482.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0032357.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0034097.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0031760.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0031248.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0032865.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0025727.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0031661.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0034041.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0027581.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0030618.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0032528.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0032825.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0029007.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0029685.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0028171.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0031143.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0033596.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0033503.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0025981.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0027048.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0028658.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0027627.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0024884.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0030430.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0030551.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0032712.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0024439.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0025162.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0031238.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0032032.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0029923.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0026776.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0026551.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0031995.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0029535.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0028562.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0026454.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0026901.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0029240.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0032619.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0027290.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0028515.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0027417.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0030645.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0028867.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0025823.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0033433.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0030077.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0030631.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0027587.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0029965.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0030127.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0033188.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0027619.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0031073.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0033350.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0028778.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0027928.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0032039.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0033247.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0033277.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0030718.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0031127.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0027520.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0030816.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0029137.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0029310.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0033851.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0033191.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0026546.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0031010.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0030379.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0032387.jpg
# ...
#   inflating: /content/ham10000Dataset/train/mel/ISIC_0034183.jpg
#   inflating: /content/ham10000Dataset/train/mel/ISIC_0030443.jpg
#   inflating: /content/ham10000Dataset/train/mel/ISIC_0028410.jpg
#   inflating: /content/ham10000Dataset/train/mel/ISIC_0033562.jpg
#   inflating: /content/ham10000Dataset/train/mel/ISIC_0032603.jpg
#   inflating: /content/ham10000Dataset/train/mel/ISIC_0033995.jpg
#   inflating: /content/ham10000Dataset/train/mel/ISIC_0028225.jpg
#   inflating: /content/ham10000Dataset/train/mel/ISIC_0031958.jpg
#   inflating: /content/ham10000Dataset/train/mel/ISIC_0026089.jpg
#   inflating: /content/ham10000Dataset/train/mel/ISIC_0033333.jpg
#   inflating: /content/ham10000Dataset/train/mel/ISIC_0033099.jpg
#   inflating: /content/ham10000Dataset/train/mel/ISIC_0031931.jpg
#   inflating: /content/ham10000Dataset/train/mel/ISIC_0024310.jpg
#   inflating: /content/ham10000Dataset/train/mel/ISIC_0024481.jpg
#   inflating: /content/ham10000Dataset/train/mel/ISIC_0034218.jpg
#   inflating: /content/ham10000Dataset/train/mel/ISIC_0028481.jpg
#   inflating: /content/ham10000Dataset/train/mel/ISIC_0031401.jpg
#   inflating: /content/ham10000Dataset/train/mel/ISIC_0033377.jpg
#   inflating: /content/ham10000Dataset/train/mel/ISIC_0033905.jpg
#   inflating: /content/ham10000Dataset/train/mel/ISIC_0032072.jpg
#   inflating: /content/ham10000Dataset/train/mel/ISIC_0029909.jpg
#   inflating: /content/ham10000Dataset/train/mel/ISIC_0029726.jpg
#   inflating: /content/ham10000Dataset/train/mel/ISIC_0028512.jpg
#   inflating: /content/ham10000Dataset/train/mel/ISIC_0034216.jpg
#   inflating: /content/ham10000Dataset/train/mel/ISIC_0031561.jpg
#   inflating: /content/ham10000Dataset/train/mel/ISIC_0026586.jpg
#   inflating: /content/ham10000Dataset/train/mel/ISIC_0032637.jpg
#   inflating: /content/ham10000Dataset/train/mel/ISIC_0032622.jpg
#   inflating: /content/ham10000Dataset/train/mel/ISIC_0030995.jpg
#   inflating: /content/ham10000Dataset/train/mel/ISIC_0026694.jpg
#   inflating: /content/ham10000Dataset/train/mel/ISIC_0025188.jpg
#   inflating: /content/ham10000Dataset/train/mel/ISIC_0028156.jpg
#   inflating: /content/ham10000Dataset/train/mel/ISIC_0031177.jpg
#   inflating: /content/ham10000Dataset/train/mel/ISIC_0025085.jpg
#   inflating: /content/ham10000Dataset/train/mel/ISIC_0033603.jpg
#   inflating: /content/ham10000Dataset/train/mel/ISIC_0033125.jpg
#   inflating: /content/ham10000Dataset/train/mel/ISIC_0032624.jpg
#   inflating: /content/ham10000Dataset/train/mel/ISIC_0032214.jpg
#   inflating: /content/ham10000Dataset/train/mel/ISIC_0025524.jpg
#   inflating: /content/ham10000Dataset/train/mel/ISIC_0033578.jpg
#   inflating: /content/ham10000Dataset/train/mel/ISIC_0029453.jpg
#   inflating: /content/ham10000Dataset/train/mel/ISIC_0033985.jpg
#   inflating: /content/ham10000Dataset/train/mel/ISIC_0028415.jpg
#   inflating: /content/ham10000Dataset/train/mel/ISIC_0026571.jpg
#   inflating: /content/ham10000Dataset/train/mel/ISIC_0024739.jpg
#   inflating: /content/ham10000Dataset/train/mel/ISIC_0027260.jpg
#   inflating: /content/ham10000Dataset/train/mel/ISIC_0033073.jpg
#   inflating: /content/ham10000Dataset/train/mel/ISIC_0030747.jpg
#   inflating: /content/ham10000Dataset/train/mel/ISIC_0024313.jpg
#   inflating: /content/ham10000Dataset/train/mel/ISIC_0030898.jpg
#   inflating: /content/ham10000Dataset/train/mel/ISIC_0034120.jpg
#   inflating: /content/ham10000Dataset/train/mel/ISIC_0030150.jpg
#   inflating: /content/ham10000Dataset/train/mel/ISIC_0027552.jpg
#   inflating: /content/ham10000Dataset/train/mel/ISIC_0028901.jpg
#   inflating: /content/ham10000Dataset/train/mel/ISIC_0032244.jpg
#   inflating: /content/ham10000Dataset/train/mel/ISIC_0032564.jpg
#   inflating: /content/ham10000Dataset/train/mel/ISIC_0025709.jpg
#   inflating: /content/ham10000Dataset/train/mel/ISIC_0033999.jpg
#   inflating: /content/ham10000Dataset/train/mel/ISIC_0032684.jpg
#   inflating: /content/ham10000Dataset/train/mel/ISIC_0033452.jpg
#   inflating: /content/ham10000Dataset/train/mel/ISIC_0026266.jpg
#   inflating: /content/ham10000Dataset/train/mel/ISIC_0032812.jpg
#   inflating: /content/ham10000Dataset/train/mel/ISIC_0025234.jpg
#   inflating: /content/ham10000Dataset/train/mel/ISIC_0033710.jpg
#   inflating: /content/ham10000Dataset/train/mel/ISIC_0033074.jpg
#   inflating: /content/ham10000Dataset/train/mel/ISIC_0026870.jpg
#   inflating: /content/ham10000Dataset/train/mel/ISIC_0033560.jpg
#   inflating: /content/ham10000Dataset/train/mel/ISIC_0032981.jpg
#   inflating: /content/ham10000Dataset/train/mel/ISIC_0027442.jpg
#   inflating: /content/ham10000Dataset/train/mel/ISIC_0027065.jpg
#   inflating: /content/ham10000Dataset/train/mel/ISIC_0025195.jpg
#   inflating: /content/ham10000Dataset/train/mel/ISIC_0027327.jpg
#   inflating: /content/ham10000Dataset/train/mel/ISIC_0033704.jpg
#   inflating: /content/ham10000Dataset/train/mel/ISIC_0032869.jpg
#   inflating: /content/ham10000Dataset/train/mel/ISIC_0032718.jpg
#   inflating: /content/ham10000Dataset/train/mel/ISIC_0025520.jpg
#   inflating: /content/ham10000Dataset/train/mel/ISIC_0033819.jpg
#   inflating: /content/ham10000Dataset/train/mel/ISIC_0025941.jpg
#   inflating: /content/ham10000Dataset/train/mel/ISIC_0029454.jpg
#   inflating: /content/ham10000Dataset/train/mel/ISIC_0028306.jpg
#   inflating: /content/ham10000Dataset/train/mel/ISIC_0033369.jpg
#   inflating: /content/ham10000Dataset/train/mel/ISIC_0031557.jpg
#   inflating: /content/ham10000Dataset/train/mel/ISIC_0033500.jpg
#   inflating: /content/ham10000Dataset/train/mel/ISIC_0025128.jpg
#   inflating: /content/ham10000Dataset/train/mel/ISIC_0029495.jpg
#   inflating: /content/ham10000Dataset/train/mel/ISIC_0028764.jpg
#   inflating: /content/ham10000Dataset/train/mel/ISIC_0034313.jpg
#   inflating: /content/ham10000Dataset/train/mel/ISIC_0026989.jpg
#   inflating: /content/ham10000Dataset/train/mel/ISIC_0033806.jpg
#   inflating: /content/ham10000Dataset/train/mel/ISIC_0031517.jpg
#   inflating: /content/ham10000Dataset/train/mel/ISIC_0031565.jpg
#   inflating: /content/ham10000Dataset/train/mel/ISIC_0024930.jpg
#   inflating: /content/ham10000Dataset/train/mel/ISIC_0028069.jpg
#   inflating: /content/ham10000Dataset/train/mel/ISIC_0031025.jpg
#   inflating: /content/ham10000Dataset/train/mel/ISIC_0033902.jpg
#   inflating: /content/ham10000Dataset/train/mel/ISIC_0027480.jpg
#   inflating: /content/ham10000Dataset/train/mel/ISIC_0024644.jpg
#   inflating: /content/ham10000Dataset/train/mel/ISIC_0030883.jpg
#   inflating: /content/ham10000Dataset/train/mel/ISIC_0026352.jpg
#   inflating: /content/ham10000Dataset/train/mel/ISIC_0025927.jpg
#   inflating: /content/ham10000Dataset/train/mel/ISIC_0027590.jpg
#   inflating: /content/ham10000Dataset/train/mel/ISIC_0033520.jpg
#   inflating: /content/ham10000Dataset/train/mel/ISIC_0032081.jpg
#   inflating: /content/ham10000Dataset/train/mel/ISIC_0028219.jpg
#   inflating: /content/ham10000Dataset/train/mel/ISIC_0031529.jpg
#   inflating: /content/ham10000Dataset/train/mel/ISIC_0025651.jpg
#   inflating: /content/ham10000Dataset/train/mel/ISIC_0033261.jpg
#   inflating: /content/ham10000Dataset/train/mel/ISIC_0032462.jpg
#   inflating: /content/ham10000Dataset/train/mel/ISIC_0026916.jpg
#   inflating: /content/ham10000Dataset/train/mel/ISIC_0032248.jpg
#   inflating: /content/ham10000Dataset/train/mel/ISIC_0034202.jpg
#   inflating: /content/ham10000Dataset/train/mel/ISIC_0032219.jpg
#   inflating: /content/ham10000Dataset/train/mel/ISIC_0030031.jpg
#   inflating: /content/ham10000Dataset/train/mel/ISIC_0032533.jpg
#   inflating: /content/ham10000Dataset/train/mel/ISIC_0032872.jpg
#   inflating: /content/ham10000Dataset/train/mel/ISIC_0024482.jpg
#   inflating: /content/ham10000Dataset/train/mel/ISIC_0033655.jpg
#   inflating: /content/ham10000Dataset/train/mel/ISIC_0032400.jpg
#   inflating: /content/ham10000Dataset/train/mel/ISIC_0032638.jpg
#   inflating: /content/ham10000Dataset/train/mel/ISIC_0033473.jpg
#   inflating: /content/ham10000Dataset/train/mel/ISIC_0032430.jpg
#   inflating: /content/ham10000Dataset/train/mel/ISIC_0027673.jpg
#   inflating: /content/ham10000Dataset/train/mel/ISIC_0032537.jpg
#   inflating: /content/ham10000Dataset/train/mel/ISIC_0032875.jpg
#   inflating: /content/ham10000Dataset/train/mel/ISIC_0029780.jpg
#   inflating: /content/ham10000Dataset/train/mel/ISIC_0026045.jpg
#   inflating: /content/ham10000Dataset/train/mel/ISIC_0032017.jpg
#   inflating: /content/ham10000Dataset/train/mel/ISIC_0024951.jpg
#   inflating: /content/ham10000Dataset/train/mel/ISIC_0024640.jpg
#   inflating: /content/ham10000Dataset/train/mel/ISIC_0032433.jpg
#   inflating: /content/ham10000Dataset/train/mel/ISIC_0028127.jpg
#   inflating: /content/ham10000Dataset/train/mel/ISIC_0028746.jpg
#   inflating: /content/ham10000Dataset/train/mel/ISIC_0027174.jpg
#   inflating: /content/ham10000Dataset/train/mel/ISIC_0033117.jpg
#   inflating: /content/ham10000Dataset/train/mel/ISIC_0031494.jpg
#   inflating: /content/ham10000Dataset/train/mel/ISIC_0030281.jpg
#   inflating: /content/ham10000Dataset/train/mel/ISIC_0034046.jpg
#   inflating: /content/ham10000Dataset/train/mel/ISIC_0032844.jpg
#   inflating: /content/ham10000Dataset/train/mel/ISIC_0032685.jpg
#   inflating: /content/ham10000Dataset/train/mel/ISIC_0029571.jpg
#   inflating: /content/ham10000Dataset/train/mel/ISIC_0034256.jpg
#   inflating: /content/ham10000Dataset/train/mel/ISIC_0027101.jpg
#   inflating: /content/ham10000Dataset/train/mel/ISIC_0028103.jpg
#   inflating: /content/ham10000Dataset/train/mel/ISIC_0027872.jpg
#   inflating: /content/ham10000Dataset/train/mel/ISIC_0031233.jpg
#   inflating: /content/ham10000Dataset/train/mel/ISIC_0027560.jpg
#   inflating: /content/ham10000Dataset/train/mel/ISIC_0026247.jpg
#   inflating: /content/ham10000Dataset/train/mel/ISIC_0034002.jpg
#   inflating: /content/ham10000Dataset/train/mel/ISIC_0032586.jpg
#   inflating: /content/ham10000Dataset/train/mel/ISIC_0033893.jpg
#   inflating: /content/ham10000Dataset/train/mel/ISIC_0024929.jpg
#   inflating: /content/ham10000Dataset/train/mel/ISIC_0028126.jpg
#   inflating: /content/ham10000Dataset/train/mel/ISIC_0030795.jpg
#   inflating: /content/ham10000Dataset/train/mel/ISIC_0024315.jpg
#   inflating: /content/ham10000Dataset/train/mel/ISIC_0029839.jpg
#   inflating: /content/ham10000Dataset/train/mel/ISIC_0032656.jpg
#   inflating: /content/ham10000Dataset/train/mel/ISIC_0027669.jpg
#   inflating: /content/ham10000Dataset/train/mel/ISIC_0025963.jpg
#   inflating: /content/ham10000Dataset/train/mel/ISIC_0024806.jpg
#   inflating: /content/ham10000Dataset/train/mel/ISIC_0033325.jpg
#   inflating: /content/ham10000Dataset/train/mel/ISIC_0032823.jpg
#   inflating: /content/ham10000Dataset/train/mel/ISIC_0033114.jpg
#   inflating: /content/ham10000Dataset/train/mel/ISIC_0033141.jpg
#   inflating: /content/ham10000Dataset/train/mel/ISIC_0030910.jpg
#   inflating: /content/ham10000Dataset/train/mel/ISIC_0029170.jpg
#   inflating: /content/ham10000Dataset/train/mel/ISIC_0031498.jpg
#   inflating: /content/ham10000Dataset/train/mel/ISIC_0028467.jpg
#   inflating: /content/ham10000Dataset/train/mel/ISIC_0032988.jpg
#   inflating: /content/ham10000Dataset/train/mel/ISIC_0027604.jpg
#   inflating: /content/ham10000Dataset/train/mel/ISIC_0026622.jpg
#   inflating: /content/ham10000Dataset/train/mel/ISIC_0026996.jpg
#   inflating: /content/ham10000Dataset/train/mel/ISIC_0029562.jpg
#   inflating: /content/ham10000Dataset/train/mel/ISIC_0027063.jpg
#   inflating: /content/ham10000Dataset/train/mel/ISIC_0028897.jpg
#   inflating: /content/ham10000Dataset/train/mel/ISIC_0033424.jpg
#   inflating: /content/ham10000Dataset/train/mel/ISIC_0027651.jpg
#   inflating: /content/ham10000Dataset/train/mel/ISIC_0028493.jpg
#   inflating: /content/ham10000Dataset/train/mel/ISIC_0028565.jpg
#   inflating: /content/ham10000Dataset/train/mel/ISIC_0028033.jpg
#   inflating: /content/ham10000Dataset/train/mel/ISIC_0031186.jpg
#   inflating: /content/ham10000Dataset/train/mel/ISIC_0026081.jpg
#   inflating: /content/ham10000Dataset/train/mel/ISIC_0025127.jpg
#   inflating: /content/ham10000Dataset/train/mel/ISIC_0030824.jpg
#   inflating: /content/ham10000Dataset/train/mel/ISIC_0024987.jpg
#   inflating: /content/ham10000Dataset/train/mel/ISIC_0029094.jpg
#   inflating: /content/ham10000Dataset/train/mel/ISIC_0032965.jpg
#   inflating: /content/ham10000Dataset/train/mel/ISIC_0026506.jpg
#   inflating: /content/ham10000Dataset/train/mel/ISIC_0026735.jpg
#   inflating: /content/ham10000Dataset/train/mel/ISIC_0030843.jpg
#   inflating: /content/ham10000Dataset/train/mel/ISIC_0034284.jpg
#   inflating: /content/ham10000Dataset/train/mel/ISIC_0034316.jpg
#   inflating: /content/ham10000Dataset/train/mel/ISIC_0030255.jpg
#   inflating: /content/ham10000Dataset/train/mel/ISIC_0025391.jpg
#   inflating: /content/ham10000Dataset/train/mel/ISIC_0033037.jpg
#   inflating: /content/ham10000Dataset/train/mel/ISIC_0033171.jpg
#   inflating: /content/ham10000Dataset/train/mel/ISIC_0028929.jpg
#   inflating: /content/ham10000Dataset/train/mel/ISIC_0028930.jpg
#   inflating: /content/ham10000Dataset/train/mel/ISIC_0024756.jpg
#   inflating: /content/ham10000Dataset/train/mel/ISIC_0026963.jpg
#   inflating: /content/ham10000Dataset/train/mel/ISIC_0029092.jpg
#   inflating: /content/ham10000Dataset/train/mel/ISIC_0031034.jpg
#   inflating: /content/ham10000Dataset/train/mel/ISIC_0029480.jpg
#   inflating: /content/ham10000Dataset/train/mel/ISIC_0025317.jpg
#   inflating: /content/ham10000Dataset/train/mel/ISIC_0024999.jpg
#   inflating: /content/ham10000Dataset/train/mel/ISIC_0030925.jpg
#   inflating: /content/ham10000Dataset/train/mel/ISIC_0033399.jpg
#   inflating: /content/ham10000Dataset/train/mel/ISIC_0033042.jpg
#   inflating: /content/ham10000Dataset/train/mel/ISIC_0030901.jpg
#   inflating: /content/ham10000Dataset/train/mel/ISIC_0027021.jpg
#   inflating: /content/ham10000Dataset/train/mel/ISIC_0033304.jpg
#   inflating: /content/ham10000Dataset/train/mel/ISIC_0027517.jpg
#   inflating: /content/ham10000Dataset/train/mel/ISIC_0033487.jpg
#   inflating: /content/ham10000Dataset/train/mel/ISIC_0024630.jpg
#   inflating: /content/ham10000Dataset/train/mel/ISIC_0027179.jpg
#   inflating: /content/ham10000Dataset/train/mel/ISIC_0030060.jpg
#   inflating: /content/ham10000Dataset/train/mel/ISIC_0029028.jpg
#   inflating: /content/ham10000Dataset/train/mel/ISIC_0033089.jpg
#   inflating: /content/ham10000Dataset/train/mel/ISIC_0025238.jpg
#   inflating: /content/ham10000Dataset/train/mel/ISIC_0034145.jpg
#   inflating: /content/ham10000Dataset/train/mel/ISIC_0024729.jpg
#   inflating: /content/ham10000Dataset/train/mel/ISIC_0030382.jpg
#   inflating: /content/ham10000Dataset/train/mel/ISIC_0030507.jpg
#   inflating: /content/ham10000Dataset/train/mel/ISIC_0027238.jpg
#   inflating: /content/ham10000Dataset/train/mel/ISIC_0034100.jpg
#   inflating: /content/ham10000Dataset/train/mel/ISIC_0032750.jpg
#   inflating: /content/ham10000Dataset/train/mel/ISIC_0033337.jpg
#   inflating: /content/ham10000Dataset/train/mel/ISIC_0030391.jpg
#   inflating: /content/ham10000Dataset/train/mel/ISIC_0026105.jpg
#   inflating: /content/ham10000Dataset/train/mel/ISIC_0030014.jpg
#   inflating: /content/ham10000Dataset/train/mel/ISIC_0033269.jpg
#   inflating: /content/ham10000Dataset/train/mel/ISIC_0026897.jpg
#   inflating: /content/ham10000Dataset/train/mel/ISIC_0033323.jpg
#   inflating: /content/ham10000Dataset/train/mel/ISIC_0026853.jpg
#   inflating: /content/ham10000Dataset/train/mel/ISIC_0028056.jpg
#   inflating: /content/ham10000Dataset/train/mel/ISIC_0030950.jpg
#   inflating: /content/ham10000Dataset/train/mel/ISIC_0027964.jpg
#   inflating: /content/ham10000Dataset/train/mel/ISIC_0028508.jpg
#   inflating: /content/ham10000Dataset/train/mel/ISIC_0030106.jpg

# %%
def visualize_augmentation(df, filepaths_col, transforms_sample, title,
                         n_rows, n_cols, n_samples=1,
                         seed=42, save_path=None, fontsize=16):
    """
    แสดงภาพต้นฉบับและภาพ Augmentation ใน Grid

    Args:
        df: DataFrame ที่มีคอลัมน์ Filepaths
        filepaths_col: ชื่อของ Column ที่เก็บตำแหน่งของรูปภาพ
        transforms_sample: list ของ tuple (name, albumentations transform)
        title: ชื่อ Title หลัก
        n_rows: จำนวนแถว
        n_cols: จำนวนหลัก
        n_samples: จำนวนภาพตัวอย่าง
        seed: random_state สำหรับ sample
        save_path: path สำหรับบันทึกรูป
        fontsize: ขนาดตัวอักษรของ title
    """
    samples = df.sample(n=n_samples, random_state=seed)

    for idx, row in samples.iterrows():
        img_path = row[filepaths_col]
        img = cv2.imread(img_path)
        if img is None:
            print(f"Error reading: {img_path}")
            continue
        img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

        n_aug = len(transforms_sample)

        fig, axes = plt.subplots(n_rows, n_cols, figsize=(4*n_cols, 4*n_rows))
        axes = axes.flatten()

        # Original image
        axes[0].imshow(img)
        axes[0].set_title("Original Image", fontsize=fontsize)
        axes[0].axis("off")

        # Augmented images
        for i, (name, aug) in enumerate(transforms_sample):
            aug_img = aug(image=img)["image"]
            axes[i+1].imshow(aug_img)
            axes[i+1].set_title(name, fontsize=fontsize)
            axes[i+1].axis("off")

        # ปิดแกนที่เหลือ
        for j in range(n_aug+1, len(axes)):
            axes[j].axis("off")

        fig.suptitle(title, fontsize=fontsize+2)
        plt.tight_layout()

        if save_path:
            plt.savefig(f"{save_path}.png", format="png", dpi=300, bbox_inches="tight")
            plt.savefig(f"{save_path}.svg", format="svg", bbox_inches="tight")

        plt.show()

# %%
def apply_transform_to_target(df, filepaths_col, labels_col, transform, base_dir, zip_dir=None,
                              max_target_ratio=0.5, max_aug_factor=4):
    """
    Args:
        df: DataFrame ของ train set
        filepaths_col: ชื่อ column ที่เก็บ path ของภาพ
        labels_col: ชื่อ column ที่เก็บ label
        transform: Albumentations transform object
        base_dir: โฟลเดอร์หลักของ dataset (สมมติว่า path ภาพเดิมอยู่ใน subfolder ของ base_dir)
        zip_dir (optional): path สำหรับ zip ผลลัพธ์ (ไม่ต้องใส่ .zip)
        max_target_ratio: augment เพิ่มจนถึงสัดส่วนเท่านี้ของคลาสใหญ่สุด (ค่าแนะนำ 0.5)
        max_aug_factor: augment ไม่เกิน x เท่าของจำนวนต้นฉบับในคลาสนั้น

    Returns:
        train_df_aug: DataFrame ของ train set หลัง augment (รวม original + augmented)
    """
    df = df.copy()
    new_rows = []

    class_counts = df[labels_col].value_counts()
    max_count = class_counts.max()

    print(f"Max class has {max_count} images")
    print(f"Augmenting minority classes (up to ratio={max_target_ratio}, max factor={max_aug_factor})\n")

    for label, count in class_counts.items():
        target_count = int(min(max_count * max_target_ratio, count * max_aug_factor))
        target_to_add = target_count - count

        if target_to_add <= 0:
            print(f"Skipping class '{label}' ({count} images)")
            continue

        print(f"\nClass '{label}': {count} → {target_count} (need +{target_to_add} new images)")
        class_df = df[df[labels_col] == label]

        sample_path = class_df[filepaths_col].iloc[0]
        class_output_dir = os.path.dirname(sample_path)

        if not os.path.exists(class_output_dir):
             print(f"Error: Output directory not found at {class_output_dir}. Skipping class {label}.")
             continue

        pbar = tqdm(total=target_to_add, desc=f"Augmenting {label}")

        for i in range(target_to_add):
            row_orig = class_df.sample(1).iloc[0]
            img_path = row_orig[filepaths_col]

            if not os.path.exists(img_path):
                 print(f"Warning: Original file not found at {img_path}, skipping augmentation for this instance.")
                 continue

            img = cv2.imread(img_path)
            if img is None:
                print(f"Error reading image: {img_path}, skipped.")
                continue

            img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
            augmented = transform(image=img)["image"]

            base_name = os.path.splitext(os.path.basename(img_path))[0]
            new_filename = f"{base_name}_aug_{i+1}.jpg"
            save_path = os.path.join(class_output_dir, new_filename)

            cv2.imwrite(save_path, cv2.cvtColor(augmented, cv2.COLOR_RGB2BGR))

            new_row = row_orig.copy()
            new_row[filepaths_col] = save_path
            new_rows.append(new_row)

            pbar.update(1)

        pbar.close()

    augmented_df = pd.DataFrame(new_rows)
    train_df_aug = pd.concat([df, augmented_df], ignore_index=True)

    if zip_dir:
        if not os.path.isabs(zip_dir):
            zip_dir = os.path.join(os.getcwd(), zip_dir)

        root_dir_zip = os.path.dirname(base_dir)
        base_dir_zip = os.path.basename(base_dir)

        if root_dir_zip and base_dir_zip:
             shutil.make_archive(zip_dir, "zip", root_dir=root_dir_zip, base_dir=base_dir_zip)
             print(f"Zip file created containing '{base_dir_zip}' folder at: {zip_dir}.zip")
        else:
             print("Warning: Could not determine base directory for zipping. Skipping zip creation.")


    print("\nAugmentation complete. New dataset size =", len(train_df_aug))
    return train_df_aug

# %%
# Geometric transform only
transform = A.Compose([
    A.RandomResizedCrop(
        (224, 224),
        scale=(0.8, 1.0), ratio=(0.9, 1.1),
        p=1.0
    ),
    A.HorizontalFlip(p=0.5),
    A.VerticalFlip(p=0.5),
    A.Affine(
        translate_percent={"x": (-0.2, 0.2), "y": (-0.2, 0.2)},
        rotate=(-45, 45),
        scale=(0.8, 1.2),
        shear=(-15, 15),
        fit_output=False,
        border_mode=cv2.BORDER_REFLECT_101,
        p=1.0
    )
], seed=SEED)

# %%
# for visualization
preview_transforms = [
    ("Horizontal Flip", A.HorizontalFlip(p=1.0)),
    ("Vertical Flip", A.VerticalFlip(p=1.0)),
    ("Translation", A.Affine(translate_percent={"x": (-0.2, 0.2), "y": (-0.2, 0.2)}, border_mode=cv2.BORDER_REFLECT_101, p=1.0)),
    ("Rotation", A.Affine(rotate=(-45, 45), border_mode=cv2.BORDER_REFLECT_101, p=1.0)),
    ("Scale", A.Affine(scale=(0.8, 1.2), border_mode=cv2.BORDER_REFLECT_101, p=1.0)),
    ("Shear", A.Affine(shear=(-15, 15), border_mode=cv2.BORDER_REFLECT_101, p=1.0)),
    ("Brightness Contrast", A.RandomBrightnessContrast(brightness_limit=(-0.2, 0.25), contrast_limit=(-0.2, 0.25), p=1.0)),
    ("Hue Saturation", A.HueSaturationValue(
        hue_shift_limit=10,
        sat_shift_limit=15,
        val_shift_limit=10,
        p=1.0
    )),
    ("Combined", A.Compose([
        A.HorizontalFlip(p=0.5),
        A.VerticalFlip(p=0.5),
        A.Affine(
            translate_percent={"x": (-0.2, 0.2), "y": (-0.2, 0.2)},
            rotate=(-45, 45),
            scale=(0.8, 1.2),
            shear=(-15, 15),
            fit_output=False,
            border_mode=cv2.BORDER_REFLECT_101,
            p=1.0
        )
    ]))
]

# %%
visualize_augmentation(
    df=df_train,
    filepaths_col="filepaths",
    transforms_sample=preview_transforms,
    title="Transformation Example",
    n_rows=2,
    n_cols=5,
    n_samples=1,
    seed=1234,
    save_path=None,
    fontsize=20
)

# %%
merge_directory(
    df_train=df_train,
    df_val=df_val,
    df_test=df_test,
    filepaths_col="filepaths",
    labels_col="dx",
    dest_dir=OVER_DATASET_DIR,
    zip_dir=None
) # สำหรับ Oversamling Train
# Out:
# Destination directory has been created at: /content/ham10000DatasetOversampling
#
# Processing train set (7832 images)...
# Copying train: 100%|██████████| 7832/7832 [01:27<00:00, 89.90it/s]
# Processing val set (984 images)...
# Copying val: 100%|██████████| 984/984 [00:11<00:00, 83.28it/s]
# Processing test set (955 images)...
# Copying test: 100%|██████████| 955/955 [00:11<00:00, 80.40it/s]

# %%
df_train, df_val, df_test = update_path(
    df_train=df_train,
    df_val=df_val,
    df_test=df_test,
    base_path=OVER_DATASET_DIR,
    filepaths_col="filepaths",
    labels_col="dx"
) # Rename path to match new path
# Out:
# Updated paths for train (7832), val (984), test (955)

# %%
df_train_transform = apply_transform_to_target(
    df=df_train,
    filepaths_col="filepaths",
    labels_col="dx",
    transform=transform,
    base_dir=OVER_DATASET_DIR,
    zip_dir=OVER_DATASET_ZIP_PATH,
    max_target_ratio=0.5,
    max_aug_factor=4
)
# Out:
# Max class has 5211 images
# Augmenting minority classes (up to ratio=0.5, max factor=4)
#
# Skipping class 'nv' (5211 images)
#
# Class 'mel': 879 → 2605 (need +1726 new images)
# Augmenting mel: 100%|██████████| 1726/1726 [00:20<00:00, 83.51it/s]
# Class 'bkl': 861 → 2605 (need +1744 new images)
# Augmenting bkl: 100%|██████████| 1744/1744 [00:21<00:00, 80.69it/s]
# Class 'bcc': 409 → 1636 (need +1227 new images)
# Augmenting bcc: 100%|██████████| 1227/1227 [00:14<00:00, 85.80it/s]
# Class 'akiec': 264 → 1056 (need +792 new images)
# Augmenting akiec: 100%|██████████| 792/792 [00:08<00:00, 97.54it/s]
# Class 'vasc': 116 → 464 (need +348 new images)
# Augmenting vasc: 100%|██████████| 348/348 [00:05<00:00, 69.54it/s]
# Class 'df': 92 → 368 (need +276 new images)
# Augmenting df: 100%|██████████| 276/276 [00:02<00:00, 95.14it/s]
# Zip file created containing 'ham10000DatasetOversampling' folder at: /content/drive/MyDrive/CP461/mainProject/datasets/ham10000DatasetOversampling.zip
#
# Augmentation complete. New dataset size = 13945

# %%
df_train_transform.to_csv(f"{INDEX_PATH}/metadata_train.csv", index=False)
df_val.to_csv(f"{INDEX_PATH}/metadata_val.csv", index=False)
df_test.to_csv(f"{INDEX_PATH}/metadata_test.csv", index=False)

# %% [markdown]
# ## **Section 8: Preparation Summary**

# %%
labels = process_df["dx"].unique().tolist()

total_count = []
train_count = []
aug_count = []
valid_count = []
test_count = []

for label in labels:
    total_count.append(process_df[process_df["dx"] == label].shape[0])
    train_count.append(df_train[df_train["dx"] == label].shape[0])
    aug_count.append(df_train_transform[df_train_transform["dx"] == label].shape[0])
    valid_count.append(df_val[df_val["dx"] == label].shape[0])
    test_count.append(df_test[df_test["dx"] == label].shape[0])

summary_df = pd.DataFrame({
    "Label": labels,
    "Total (100%)": total_count,
    "Train (80.16%)": train_count,
    "Augmented": aug_count,
    "Valid (10.07%)": valid_count,
    "Test (9.77%)": test_count
})
summary_df.to_csv(f"{INDEX_PATH}/dataset_description.csv", index=False)

print("Dataset overall description")
print("=======================================================================================================")
print(summary_df.to_string(index=False))
print("=======================================================================================================")
print(f"Training total count: {sum(train_count)}")
print(f"Augmented total count: {sum(aug_count)}")
print(f"Validation total count: {sum(valid_count)}")
print(f"Testing total count: {sum(test_count)}")
# Out:
# Dataset overall description
# =======================================================================================================
# Label  Total (100%)  Train (80.16%)  Augmented  Valid (10.07%)  Test (9.77%)
#   bkl          1076             861       2605             117            98
#    nv          6499            5211       5211             651           637
#    df           115              92        368              12            11
#   mel          1103             879       2605             107           117
#  vasc           142             116        464              15            11
#   bcc           509             409       1636              52            48
# akiec           327             264       1056              30            33
# =======================================================================================================
# Training total count: 7832
# Augmented total count: 13945
# Validation total count: 984
# Testing total count: 955

# %% [markdown]
# ## **Section 9: Preprocess Metadata**

# %%
df_train = pd.read_csv(f"{INDEX_PATH}/metadata_train.csv")
df_val = pd.read_csv(f"{INDEX_PATH}/metadata_val.csv")
df_test = pd.read_csv(f"{INDEX_PATH}/metadata_test.csv")

print(f"Train shape: {df_train.shape}")
print(f"Validation shape:   {df_val.shape}")
print(f"Test shape:  {df_test.shape}")
# Out:
# Train shape: (13945, 10)
# Validation shape:   (984, 10)
# Test shape:  (955, 10)

# %%
numeric_cols = ["age"]
categorical_cols = ["sex", "localization"] # ไม่รวม Target
target_col = "cell_type_idx"
filepath_col = "filepaths"

# %% [markdown]
# ### **For tab transformer**

# %%
numeric_transformer = sklearn.pipeline.Pipeline(steps=[
    ("imputer", sklearn.impute.SimpleImputer(strategy="median")),
    ("scaler", sklearn.preprocessing.StandardScaler())
])

categorical_transformer = sklearn.pipeline.Pipeline(steps=[
    ("imputer", sklearn.impute.SimpleImputer(strategy="most_frequent")),
    ("ordinal", sklearn.preprocessing.OrdinalEncoder(
        handle_unknown="use_encoded_value",
        unknown_value=-1
    ))
])

# %%
transformer_preprocessor = sklearn.compose.ColumnTransformer(
    transformers=[
        ("numeric", numeric_transformer, numeric_cols),
        ("categorical", categorical_transformer, categorical_cols)
    ],
    remainder="drop"
)

print("Fitting preprocessor (for TabTransformer)...")
transformer_preprocessor.fit(df_train)
# Out:
# Fitting preprocessor (for TabTransformer)...
# ColumnTransformer(transformers=[('numeric',
#                                  Pipeline(steps=[('imputer',
#                                                   SimpleImputer(strategy='median')),
#                                                  ('scaler', StandardScaler())]),
#                                  ['age']),
#                                 ('categorical',
#                                  Pipeline(steps=[('imputer',
#                                                   SimpleImputer(strategy='most_frequent')),
#                                                  ('ordinal',
#                                                   OrdinalEncoder(handle_unknown='use_encoded_value',
#                                                                  unknown_value=-1))]),
#                                  ['sex', 'localization'])])

# %%
joblib.dump(transformer_preprocessor, f"{INDEX_PATH}/tab_transformer_preprocess.joblib")
print("Preprocessors saved!")
# Out:
# Preprocessors saved!

# %% [markdown]
# ### **For multi-layers perceptron**

# %%
numeric_mlp = sklearn.pipeline.Pipeline(steps=[
    ("imputer", sklearn.impute.SimpleImputer(strategy="median")),
    ("scaler", sklearn.preprocessing.StandardScaler())
])

categorical_mlp = sklearn.pipeline.Pipeline(steps=[
    ("imputer", sklearn.impute.SimpleImputer(strategy="most_frequent")),
    ("onehot", sklearn.preprocessing.OneHotEncoder(
        handle_unknown="ignore"
    ))
])

# %%
mlp_preprocessor = sklearn.compose.ColumnTransformer(
    transformers=[
        ("numeric", numeric_mlp, numeric_cols),
        ("categorical", categorical_mlp, categorical_cols)
    ],
    remainder="drop"
)

print("Fitting preprocessor (for MLP)...")
mlp_preprocessor.fit(df_train)
# Out:
# Fitting preprocessor (for MLP)...
# ColumnTransformer(transformers=[('numeric',
#                                  Pipeline(steps=[('imputer',
#                                                   SimpleImputer(strategy='median')),
#                                                  ('scaler', StandardScaler())]),
#                                  ['age']),
#                                 ('categorical',
#                                  Pipeline(steps=[('imputer',
#                                                   SimpleImputer(strategy='most_frequent')),
#                                                  ('onehot',
#                                                   OneHotEncoder(handle_unknown='ignore'))]),
#                                  ['sex', 'localization'])])

# %%
joblib.dump(mlp_preprocessor, f"{INDEX_PATH}/mlp_preprocess.joblib")
print("Preprocessors saved!")
# Out:
# Preprocessors saved!
